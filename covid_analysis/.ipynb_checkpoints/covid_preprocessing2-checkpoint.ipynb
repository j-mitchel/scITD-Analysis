# %%
import scanpy as sc
import pandas as pd
import numpy as np
import scipy

# %%
pbmc1 = sc.read_h5ad('/home/jmitchel/data/covid_data/COVID19_ALL.h5ad')

# %%
# checking quality metrics
pbmc1.var['mt'] = pbmc1.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
sc.pp.calculate_qc_metrics(pbmc1, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(pbmc1, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
             jitter=0.4, multi_panel=True)

# %%
max(pbmc1.obs.pct_counts_mt)
# Out:
# 6.361462116241455

# %%
## looks okay in terms of QC metrics, though there are probably some doublets

# %%
# len(set(pbmc1.obs.sampleID)) #284 samples as expected
# len(set(pbmc1.obs.PatientID)) #196 individuals as expected (some individuals have > 1 sample)
# Out:
# AACAGGGGTCGGATTT-0    S-S070-1
# AACCAACGTCCGAAAG-0    S-S070-1
# AACCTTTGTAGCACGA-0    S-S070-1
# AAGCATCTCTATCGCC-0    S-S070-1
# AATCACGGTCATAAAG-0    S-S070-1
# AATCACGGTGGTTCTA-0    S-S070-1
# AATGAAGCAACTGGTT-0    S-S070-1
# AATGAAGCACCAGCGT-0    S-S070-1
# AATGCCATCACCTCGT-0    S-S070-1
# AATGGCTCAAGGCTTT-0    S-S070-1
# Name: sampleID, dtype: category
# Categories (284, object): ['S-HC001', 'S-HC002', 'S-HC003', 'S-HC004', ..., 'S-S090-1', 'S-S090-2', 'S-S091', 'S-S092']

# %%
# checking what different metadata fields are available
pbmc1
# Out:
# AnnData object with n_obs × n_vars = 1462702 × 27943
#     obs: 'celltype', 'majorType', 'sampleID', 'PatientID', 'datasets', 'City', 'Age', 'Sex', 'Sample type', 'CoVID-19 severity', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_tsne', 'har_emb'
#     obsp: 'connectivities', 'distances'

# %%
## looking at the cell type annotations
# set(pbmc1.obs.majorType)
set(pbmc1.obs['Sample type'])
# Out:
# {'B cells sorted from frozen PBMC (MACS, STEMCELL 19054)',
#  'CD19+ B cell sorted from fresh PBMC (FACS)',
#  'CD19+ B cell sorted from fresh PBMC (MACS)',
#  'CD3+ T cell and CD19+ B cell sorted from fresh PBMC (FACS)',
#  'CD3+ T cell sorted from fresh PBMC (FACS)',
#  'fresh BALF',
#  'fresh PBMC',
#  'fresh PFMC',
#  'fresh Sputum',
#  'frozen PBMC'}

# %%
## subset to only include cells of non-isolated fresh PBMC's
m1 = pbmc1.obs['Sample type'] == 'fresh PBMC' 
m2 = pbmc1.obs['Sample type'] == 'frozen PBMC' 
m3 = m1 | m2
print(m1[:10])
print(m2[:10])
print(m3[:10])

pbmc2 = pbmc1[m3, :]
# Out:
# AACAGGGGTCGGATTT-0    False
# AACCAACGTCCGAAAG-0    False
# AACCTTTGTAGCACGA-0    False
# AAGCATCTCTATCGCC-0    False
# AATCACGGTCATAAAG-0    False
# AATCACGGTGGTTCTA-0    False
# AATGAAGCAACTGGTT-0    False
# AATGAAGCACCAGCGT-0    False
# AATGCCATCACCTCGT-0    False
# AATGGCTCAAGGCTTT-0    False
# Name: Sample type, dtype: bool
# AACAGGGGTCGGATTT-0    True
# AACCAACGTCCGAAAG-0    True
# AACCTTTGTAGCACGA-0    True
# AAGCATCTCTATCGCC-0    True
# AATCACGGTCATAAAG-0    True
# AATCACGGTGGTTCTA-0    True
# AATGAAGCAACTGGTT-0    True
# AATGAAGCACCAGCGT-0    True
# AATGCCATCACCTCGT-0    True
# AATGGCTCAAGGCTTT-0    True
# Name: Sample type, dtype: bool
# AACAGGGGTCGGATTT-0    True
# AACCAACGTCCGAAAG-0    True
# AACCTTTGTAGCACGA-0    True
# AAGCATCTCTATCGCC-0    True
# AATCACGGTCATAAAG-0    True
# AATCACGGTGGTTCTA-0    True
# AATGAAGCAACTGGTT-0    True
# AATGAAGCACCAGCGT-0    True
# AATGCCATCACCTCGT-0    True
# AATGGCTCAAGGCTTT-0    True
# Name: Sample type, dtype: bool

# %%
pbmc2 # left with 542075 cells when only fresh pbmcs... 993171 when include both fresh and frozen
# Out:
# View of AnnData object with n_obs × n_vars = 993171 × 27943
#     obs: 'celltype', 'majorType', 'sampleID', 'PatientID', 'datasets', 'City', 'Age', 'Sex', 'Sample type', 'CoVID-19 severity', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_tsne', 'har_emb'
#     obsp: 'connectivities', 'distances'

# %%
print(len(set(pbmc2.obs.sampleID))) #83 samples left with just fresh pbmc ... 172 when include frozen
print(len(set(pbmc2.obs.PatientID))) #79 individuals left with just fresh pbmc ... 151 when include frozen
# Out:
# 172
# 151

# %%
# seeing if the patients with multiple samples have like two progression samples or one progression one conv
all_donors = set(pbmc2.obs.PatientID)
samp_keep = [] # store samples to keep
for d in all_donors:
    tmp = pbmc2[pbmc2.obs.PatientID==d,]
    samp_keep.append(list(set(tmp.obs.sampleID))[0]) #arbitrarily select the first sample to keep for analysis
#     print(d)
#     print(len(set(tmp.obs.sampleID)))
#     print(set(tmp.obs['Sample time']))
#     print('')

# %%
print(len(samp_keep))
samp_keep[:10]
# Out:
# 151
# ['S-S083',
#  'S-M046',
#  'S-M006',
#  'S-S015',
#  'S-M054',
#  'S-S033',
#  'S-S037',
#  'S-M067',
#  'S-S041',
#  'S-S040']

# %%
# subset data to just selected samples so that each donor only has one
samp_mask = [True if x in samp_keep else False for x in pbmc2.obs.sampleID]
pbmc3 = pbmc2[samp_mask, :]

# %%
pbmc3
# Out:
# View of AnnData object with n_obs × n_vars = 945817 × 27943
#     obs: 'celltype', 'majorType', 'sampleID', 'PatientID', 'datasets', 'City', 'Age', 'Sex', 'Sample type', 'CoVID-19 severity', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_tsne', 'har_emb'
#     obsp: 'connectivities', 'distances'

# %%
# double checking we only have one sample per donor
all_donors = set(pbmc3.obs.PatientID)
for d in all_donors:
    tmp = pbmc3[pbmc3.obs.PatientID==d,]
    print(d)
    print(len(set(tmp.obs.sampleID)))
    print(set(tmp.obs['Sample time']))
    print('')
# Out:
# P-S083
# 1
# {'convalescence'}
#
# P-M046
# 1
# {'progression'}
#
# P-M006
# 1
# {'convalescence'}
#
# P-S015
# 1
# {'convalescence'}
#
# P-M054
# 1
# {'convalescence'}
#
# P-S033
# 1
# {'convalescence'}
#
# P-S037
# 1
# {'progression'}
#
# P-M067
# 1
# {'progression'}
#
# P-S041
# 1
# {'progression'}
#
# P-S040
# 1
# {'progression'}
#
# P-S057
# 1
# {'progression'}
#
# P-M073
# 1
# {'convalescence'}
#
# P-S032
# 1
# {'progression'}
#
# P-M026
# 1
# {'convalescence'}
#
# P-M037
# 1
# {'convalescence'}
#
# P-M045
# 1
# {'convalescence'}
#
# P-HC005
# 1
# {'control'}
#
# P-S088
# 1
# {'progression'}
#
# P-S017
# 1
# {'convalescence'}
#
# P-M077
# 1
# {'progression'}
#
# P-S048
# 1
# {'progression'}
#
# P-S050
# 1
# {'progression'}
#
# P-M019
# 1
# {'convalescence'}
#
# P-M079
# 1
# {'progression'}
#
# P-M022
# 1
# {'convalescence'}
#
# P-HC015
# 1
# {'control'}
#
# P-S085
# 1
# {'progression'}
#
# P-M043
# 1
# {'convalescence'}
#
# P-M024
# 1
# {'convalescence'}
#
# P-S044
# 1
# {'progression'}
#
# P-S067
# 1
# {'convalescence'}
#
# P-S056
# 1
# {'progression'}
#
# P-S081
# 1
# {'convalescence'}
#
# P-S080
# 1
# {'convalescence'}
#
# P-S053
# 1
# {'progression'}
#
# P-HC009
# 1
# {'control'}
#
# P-S039
# 1
# {'progression'}
#
# P-S071
# 1
# {'progression'}
#
# P-S035
# 1
# {'convalescence'}
#
# P-S060
# 1
# {'convalescence'}
#
# P-S034
# 1
# {'convalescence'}
#
# P-M065
# 1
# {'convalescence'}
#
# P-S069
# 1
# {'progression'}
#
# P-HC021
# 1
# {'control'}
#
# P-S061
# 1
# {'progression'}
#
# P-HC013
# 1
# {'control'}
#
# P-M047
# 1
# {'progression'}
#
# P-M042
# 1
# {'progression'}
#
# P-M009
# 1
# {'convalescence'}
#
# P-M039
# 1
# {'convalescence'}
#
# P-HC011
# 1
# {'control'}
#
# P-M020
# 1
# {'convalescence'}
#
# P-M078
# 1
# {'progression'}
#
# P-HC007
# 1
# {'control'}
#
# P-M044
# 1
# {'progression'}
#
# P-S070
# 1
# {'progression'}
#
# P-M029
# 1
# {'convalescence'}
#
# P-S029
# 1
# {'convalescence'}
#
# P-S078
# 1
# {'convalescence'}
#
# P-S028
# 1
# {'convalescence'}
#
# P-M068
# 1
# {'progression'}
#
# P-S043
# 1
# {'progression'}
#
# P-S079
# 1
# {'convalescence'}
#
# P-M072
# 1
# {'convalescence'}
#
# P-HC016
# 1
# {'control'}
#
# P-M018
# 1
# {'convalescence'}
#
# P-M021
# 1
# {'convalescence'}
#
# P-M051
# 1
# {'convalescence'}
#
# P-S019
# 1
# {'convalescence'}
#
# P-HC014
# 1
# {'control'}
#
# P-S066
# 1
# {'convalescence'}
#
# P-S045
# 1
# {'progression'}
#
# P-M031
# 1
# {'convalescence'}
#
# P-M050
# 1
# {'convalescence'}
#
# P-M066
# 1
# {'progression'}
#
# P-HC003
# 1
# {'control'}
#
# P-S042
# 1
# {'progression'}
#
# P-M057
# 1
# {'progression'}
#
# P-S084
# 1
# {'convalescence'}
#
# P-HC023
# 1
# {'control'}
#
# P-S052
# 1
# {'progression'}
#
# P-M011
# 1
# {'convalescence'}
#
# P-M017
# 1
# {'convalescence'}
#
# P-S063
# 1
# {'convalescence'}
#
# P-M035
# 1
# {'convalescence'}
#
# P-M040
# 1
# {'convalescence'}
#
# P-HC010
# 1
# {'control'}
#
# P-M034
# 1
# {'convalescence'}
#
# P-M030
# 1
# {'convalescence'}
#
# P-HC006
# 1
# {'control'}
#
# P-S030
# 1
# {'convalescence'}
#
# P-S031
# 1
# {'convalescence'}
#
# P-S020
# 1
# {'convalescence'}
#
# P-S051
# 1
# {'progression'}
#
# P-M005
# 1
# {'convalescence'}
#
# P-M027
# 1
# {'convalescence'}
#
# P-M049
# 1
# {'progression'}
#
# P-S077
# 1
# {'convalescence'}
#
# P-S013
# 1
# {'convalescence'}
#
# P-S014
# 1
# {'convalescence'}
#
# P-S082
# 1
# {'convalescence'}
#
# P-S072
# 1
# {'progression'}
#
# P-S018
# 1
# {'convalescence'}
#
# P-S054
# 1
# {'progression'}
#
# P-S068
# 1
# {'convalescence'}
#
# P-M052
# 1
# {'convalescence'}
#
# P-S001
# 1
# {'progression'}
#
# P-S036
# 1
# {'progression'}
#
# P-M012
# 1
# {'convalescence'}
#
# P-M071
# 1
# {'convalescence'}
#
# P-M055
# 1
# {'convalescence'}
#
# P-S047
# 1
# {'progression'}
#
# P-S038
# 1
# {'progression'}
#
# P-S016
# 1
# {'convalescence'}
#
# P-HC022
# 1
# {'control'}
#
# P-S065
# 1
# {'convalescence'}
#
# P-S059
# 1
# {'progression'}
#
# P-M001
# 1
# {'convalescence'}
#
# P-S091
# 1
# {'convalescence'}
#
# P-M032
# 1
# {'convalescence'}
#
# P-M025
# 1
# {'convalescence'}
#
# P-M074
# 1
# {'progression'}
#
# P-M038
# 1
# {'convalescence'}
#
# P-M064
# 1
# {'convalescence'}
#
# P-S086
# 1
# {'progression'}
#
# P-M036
# 1
# {'convalescence'}
#
# P-M053
# 1
# {'convalescence'}
#
# P-S089
# 1
# {'progression'}
#
# P-HC017
# 1
# {'control'}
#
# P-S090
# 1
# {'progression'}
#
# P-M069
# 1
# {'convalescence'}
#
# P-M041
# 1
# {'progression'}
#
# P-M056
# 1
# {'progression'}
#
# P-S046
# 1
# {'progression'}
#
# P-HC025
# 1
# {'control'}
#
# P-M048
# 1
# {'convalescence'}
#
# P-S049
# 1
# {'progression'}
#
# P-HC008
# 1
# {'control'}
#
# P-S062
# 1
# {'convalescence'}
#
# P-HC004
# 1
# {'control'}
#
# P-S092
# 1
# {'progression'}
#
# P-S064
# 1
# {'convalescence'}
#
# P-S055
# 1
# {'progression'}
#
# P-M076
# 1
# {'progression'}
#
# P-M028
# 1
# {'convalescence'}
#
# P-M070
# 1
# {'convalescence'}
#
# P-S058
# 1
# {'progression'}
#
# P-S087
# 1
# {'progression'}
#
# P-HC012
# 1
# {'control'}
#
# P-HC024
# 1
# {'control'}
#
# P-M023
# 1
# {'convalescence'}

# %%
pbmc3.write('/home/jmitchel/data/covid_data/COVID19_subset.h5ad')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_97229/3000984512.py in <module>
# ----> 1 pbmc3.write('/home/jmitchel/data/covid_data/COVID19_subset.h5ad')
#
# NameError: name 'pbmc3' is not defined

# %%
## trying to downgrade anndata to see if it fixes the error in seurat with R
# !pip install anndata==0.6.22.post1
# Out:
# Collecting anndata==0.6.22.post1
#   Downloading anndata-0.6.22.post1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.2 MB/s eta 0:00:011
# Requirement already satisfied: pandas>=0.23.0 in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from anndata==0.6.22.post1) (1.3.1)
# Requirement already satisfied: natsort in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from anndata==0.6.22.post1) (7.1.1)
# Requirement already satisfied: numpy~=1.14 in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from anndata==0.6.22.post1) (1.21.1)
# Requirement already satisfied: h5py in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from anndata==0.6.22.post1) (3.3.0)
# Requirement already satisfied: scipy~=1.0 in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from anndata==0.6.22.post1) (1.7.1)
# Requirement already satisfied: pytz>=2017.3 in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from pandas>=0.23.0->anndata==0.6.22.post1) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from pandas>=0.23.0->anndata==0.6.22.post1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /d0/home/jmitchel/miniconda3/envs/sandbox/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->anndata==0.6.22.post1) (1.16.0)
# Installing collected packages: anndata
#   Attempting uninstall: anndata
#     Found existing installation: anndata 0.7.6
#     Uninstalling anndata-0.7.6:
#       Successfully uninstalled anndata-0.7.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scanpy 1.8.1 requires anndata>=0.7.4, but you have anndata 0.6.22.post1 which is incompatible.
# Successfully installed anndata-0.6.22.post1

# %%
## trying to save as loom file, then downgrade h5py then load loom and export the h5 file again
pbmc3.write_loom('/home/jmitchel/data/covid_data/COVID19_subset.loom')
# Out:
# The loom file will lack these fields:
# {'har_emb', 'X_tsne', 'X_pca'}
# Use write_obsm_varm=True to export multi-dimensional annotations
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_83395/4136085893.py in <module>
#       1 ## trying to save as loom file, then downgrade h5py then load loom and export the h5 file again
# ----> 2 pbmc3.write_loom('/home/jmitchel/data/covid_data/COVID19_subset.loom')
#
# ~/miniconda3/envs/sandbox/lib/python3.8/site-packages/anndata/_core/anndata.py in write_loom(self, filename, write_obsm_varm)
#
# ~/miniconda3/envs/sandbox/lib/python3.8/site-packages/anndata/_io/write.py in write_loom(filename, adata, write_obsm_varm)
#
# ~/miniconda3/envs/sandbox/lib/python3.8/site-packages/loompy/loompy.py in create(filename, layers, row_attrs, col_attrs, file_attrs)
#    1066
#    1067                         for key, vals in col_attrs.items():
# -> 1068                                 ds.ca[key] = vals
#    1069
#    1070         except ValueError as ve:
#
# ~/miniconda3/envs/sandbox/lib/python3.8/site-packages/loompy/attribute_manager.py in __setitem__(self, name, val)
#     127                 Set the value of a named attribute
#     128 		"""
# --> 129                 return self.__setattr__(name, val)
#     130
#     131         def __setattr__(self, name: str, val: np.ndarray) -> None:
#
# ~/miniconda3/envs/sandbox/lib/python3.8/site-packages/loompy/attribute_manager.py in __setattr__(self, name, val)
#     144                         super(AttributeManager, self).__setattr__(name[1:], val)
#     145                 elif "/" in name:
# --> 146                         raise KeyError("Attribute name cannot contain slash (/)")
#     147                 else:
#     148                         if self.ds is not None:
#
# KeyError: 'Attribute name cannot contain slash (/)'

# %%
# restarted kernel.. will reload data and try to resave it...
pbmc3 = sc.read_h5ad('/home/jmitchel/data/covid_data/COVID19_subset.h5ad')

# %%
## check that the "raw" elements are the same dimensions as the full elements
## if not, then can subset them too and try again
## if they are correct, I can try exporting just the raw data as matrices
## for this i'd need to see what format the raw matrix is in...

# print(pbmc3.raw.X[0:100,0:10])
# print(pbmc3.X[0:10,0:10])
# pbmc3.X.shape
# pbmc3.raw.X.shape
# print(sum(pbmc3.raw.X==0))

# %%
# trying to export anndata as csvs though this is probably a terrible idea
print(9)
# Out:
# 9

# %%
scipy.io.mmwrite('/home/jmitchel/data/covid_data/COVID19_subset.mtx', pbmc3.raw.X)
# Out:
# AnnData object with n_obs × n_vars = 945817 × 27943
#     obs: 'celltype', 'majorType', 'sampleID', 'PatientID', 'datasets', 'City', 'Age', 'Sex', 'Sample type', 'CoVID-19 severity', 'Sample time', 'Sampling day (Days after symptom onset)', 'SARS-CoV-2', 'Single cell sequencing platform', 'BCR single cell sequencing', 'TCR single cell sequencing', 'Outcome', 'Comorbidities', 'COVID-19-related medication and anti-microbials', 'Leukocytes [G/L]', 'Neutrophils [G/L]', 'Lymphocytes [G/L]', 'Unpublished', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_tsne', 'har_emb'
#     obsp: 'connectivities', 'distances'
